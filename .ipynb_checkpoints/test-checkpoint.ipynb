# %% [markdown]
# # Beschrijvende data anaylse in python

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Data bestanden uitlezen met df en een 10 row preview tabel tonen van de data

# %%
df = pd.read_csv("Kaggle_TED_video_metadata_balanced.csv")
df.head(n=10)
# Out:
#                                                title  \
# 0  Stories from a home for terminally ill childre...
# 1    Why our screens make us less happy | Adam Alter
# 2                A tribute to nurses | Carolyn Jones
# 3  Asking for help is a strength, not a weakness ...
# 4  Don't feel sorry for refugees -- believe in th...
# 5  Lifesaving scientific tools made of paper | Ma...
# 6  The family I lost in North Korea. And the fami...
# 7  Meet Spot, the robot dog that can run, hop and...
# 8  Jorge Ramos: Why journalists have an obligatio...
# 9  What I learned from 100 days of rejection | Ji...
#
#                                                 tags    views   likes  \
# 0  TED Talk,TED Talks,Children,Community,Death,Fa...    77455    1768
# 1  TEDTalk,TEDTalks,Addiction,Computers,Interface...   800326   20579
# 2  TEDTalk,TEDTalks,Cancer,Community,Compassion,D...    87635    1877
# 3  TEDTalk,TEDTalks,Children,Communication,Commun...   190840    4726
# ...

# %% [markdown]
# ### De aantallen, gemiddeldes, deviations en andere interessante gegevens tonen over de numerieke waarden in de data.

# %%
df.describe()
# Out:
#               views         likes  dislikes  comment_count  category_id
# count  6.000000e+02  6.000000e+02     600.0     600.000000   600.000000
# mean   1.066151e+06  2.263473e+04       0.0    1070.870000    25.030000
# std    3.611008e+06  1.000825e+05       0.0    4055.503954     4.812244
# min    1.000000e+00  0.000000e+00       0.0       0.000000     1.000000
# 25%    5.922150e+04  6.242500e+02       0.0      86.000000    22.000000
# 50%    1.332595e+05  1.846000e+03       0.0     202.000000    27.000000
# 75%    4.101668e+05  6.382250e+03       0.0     511.750000    28.000000
# max    5.562224e+07  1.921445e+06       0.0   77980.000000    29.000000

# %%
df['category_id'].value_counts()
# Out:
# category_id
# 28    222
# 22    116
# 27     66
# 29     54
# 25     45
# 24     37
# 10     20
# 26     11
# 15      8
# 19      7
# 1       4
# 20      3
# 2       3
# 23      2
# 17      2
# Name: count, dtype: int64
